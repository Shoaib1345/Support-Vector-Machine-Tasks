# %% [markdown]
# # <font color="purple"><h3 align="center"> Implement SVM using hyperparameter Tuning on Hotel_Bookings_Clean</h3></font>

# %%
import pandas as pd
import numpy as np
from sklearn.matrics import accuray_score
from sklearn.model_selection import train_test_split
from sklearn.model_selection import RandomizedSearchCV

# %%
hostel=pd.read_csv('hotel_bookings_clean.csv')
hostel
# Out:
#       is_canceled  lead_time  arrival_date_week_number  \
# 0               0         68                        14
# 1               0        152                        14
# 2               0         11                        49
# 3               1          6                        27
# 4               1        335                        38
# ...           ...        ...                       ...
# 1495            1         31                        16
# 1496            0         84                        37
# 1497            1        315                        49
# 1498            0        105                         1
# 1499            0         18                        30
#
#       stays_in_weekend_nights  stays_in_week_nights  adults  \
# 0                           2                     3       2
# 1                           1                     4       1
# 2                           0                     3       1
# ...

# %%
hostel.shape
# Out:
# (1500, 16)

# %%
hostel.head(10)
# Out:
#    is_canceled  lead_time  arrival_date_week_number  stays_in_weekend_nights  \
# 0            0         68                        14                        2
# 1            0        152                        14                        1
# 2            0         11                        49                        0
# 3            1          6                        27                        0
# 4            1        335                        38                        0
# 5            0        188                        40                        1
# 6            0        276                        39                        0
# 7            0          2                        40                        0
# 8            1        279                        21                        0
# 9            0         49                        42                        0
#
#    stays_in_week_nights  adults  is_repeated_guest  previous_cancellations  \
# ...

# %%
hostel.isna().sum()
# Out:
# is_canceled                      0
# lead_time                        0
# arrival_date_week_number         0
# stays_in_weekend_nights          0
# stays_in_week_nights             0
# adults                           0
# is_repeated_guest                0
# previous_cancellations           0
# total_of_special_requests        0
# avg_daily_rate                   0
# booked_by_company                0
# booked_by_agent                  0
# customer_type_Contract           0
# customer_type_Group              0
# customer_type_Transient          0
# customer_type_Transient-Party    0
# dtype: int64

# %%
hostel.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1500 entries, 0 to 1499
# Data columns (total 16 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   is_canceled                    1500 non-null   int64
#  1   lead_time                      1500 non-null   int64
#  2   arrival_date_week_number       1500 non-null   int64
#  3   stays_in_weekend_nights        1500 non-null   int64
#  4   stays_in_week_nights           1500 non-null   int64
#  5   adults                         1500 non-null   int64
#  6   is_repeated_guest              1500 non-null   int64
#  7   previous_cancellations         1500 non-null   int64
#  8   total_of_special_requests      1500 non-null   int64
#  9   avg_daily_rate                 1500 non-null   float64
#  10  booked_by_company              1500 non-null   int64
#  11  booked_by_agent                1500 non-null   int64
# ...

# %%
X=hostel.iloc[:,1:]
Y=hostel['is_canceled']
X
# Out:
#       lead_time  arrival_date_week_number  stays_in_weekend_nights  \
# 0            68                        14                        2
# 1           152                        14                        1
# 2            11                        49                        0
# 3             6                        27                        0
# 4           335                        38                        0
# ...         ...                       ...                      ...
# 1495         31                        16                        0
# 1496         84                        37                        0
# 1497        315                        49                        0
# 1498        105                         1                        1
# 1499         18                        30                        1
#
#       stays_in_week_nights  adults  is_repeated_guest  previous_cancellations  \
# 0                        3       2                  0                       0
# ...

# %%
X_train,x_test,Y_train,y_test=train_test_split(X,Y,test_size=0.2, random_state=123)
hyperparams={'kernel':'linear',
       'C':1,
       'gamma':0.01,
       'degree':3,
      'random_state':123}

# %%
rs_param_grid={'kernel':['linear','poly','rbf','sigmoid'],
       'C':[0.1,1,10],
       'gamma':[0.00001,0.0001,0.001,0.01,0.1]
       }

# %%
from sklearn.svm import SVC
clfs=SVC(**hyperparams)
clfs.fit(X_train,Y_train)
# Out:
# SVC(C=1, gamma=0.01, kernel='linear', random_state=123)

# %%
test_prediction=clfs.predict(x_test)

# %%
acc=accuracy_score(test_prediction,y_test)
acc
# Out:
# 0.75

# %%
clf=SVC(random_state=123)
clf_rs=RandomizedSearchCV(estimator=clf,
                         param_distributions=rs_param_grid,
                         cv=3,
                         n_iter=5,
                         verbose=2,
                         random_state=123)

# %%
clf_rs.fit(X_train,Y_train)
# Out:
# Fitting 3 folds for each of 5 candidates, totalling 15 fits
# [CV] END ...................C=1, gamma=0.0001, kernel=linear; total time=   6.2s
# [CV] END ...................C=1, gamma=0.0001, kernel=linear; total time=   3.4s
# [CV] END ...................C=1, gamma=0.0001, kernel=linear; total time=   6.9s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END .....................C=1, gamma=0.1, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ..................C=0.1, gamma=0.01, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# [CV] END ...................C=1, gamma=0.001, kernel=sigmoid; total time=   0.0s
# ...

# %%
print(clf_rs.best_params_)
print(clf_rs.best_score_)
# Out:
# {'kernel': 'linear', 'gamma': 0.0001, 'C': 1}
# 0.7358333333333333

# %% [markdown]
# # <font color="purple"><h3 align="center">Implement SVM on Iris Dataset</h3></font>

# %%
#task 02
from sklearn.datasets import load_iris
iris=load_iris()

# %%
X=iris.data
Y=iris.target

# %%
iris_pd=pd.DataFrame(data=X, columns=iris.feature_names)
iris_pd['target']=Y
iris_pd
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                  5.1               3.5                1.4               0.2
# 1                  4.9               3.0                1.4               0.2
# 2                  4.7               3.2                1.3               0.2
# 3                  4.6               3.1                1.5               0.2
# 4                  5.0               3.6                1.4               0.2
# ..                 ...               ...                ...               ...
# 145                6.7               3.0                5.2               2.3
# 146                6.3               2.5                5.0               1.9
# 147                6.5               3.0                5.2               2.0
# 148                6.2               3.4                5.4               2.3
# 149                5.9               3.0                5.1               1.8
#
#      target
# 0         0
# ...

# %%
X=iris_pd.drop('target',axis=1)
Y=iris_pd['target']
Y
# Out:
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0
#       ..
# 145    2
# 146    2
# 147    2
# 148    2
# 149    2
# Name: target, Length: 150, dtype: int32

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test=train_test_split(X,Y, test_size=0.2, random_state=43)
X_test
# Out:
#      sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 30                 4.8               3.1                1.6               0.2
# 0                  5.1               3.5                1.4               0.2
# 138                6.0               3.0                4.8               1.8
# 67                 5.8               2.7                4.1               1.0
# 105                7.6               3.0                6.6               2.1
# 39                 5.1               3.4                1.5               0.2
# 113                5.7               2.5                5.0               2.0
# 71                 6.1               2.8                4.0               1.3
# 81                 5.5               2.4                3.7               1.0
# 57                 4.9               2.4                3.3               1.0
# 38                 4.4               3.0                1.3               0.2
# ...

# %%
from sklearn.svm import SVC
svc_model=SVC(kernel='linear', C=1.0)
svc_model.fit(X_train,Y_train)
# Out:
# SVC(kernel='linear')

# %%
test_prediction=svc_model.predict(X_test)
train_pre=svc_model.predict(X_train)

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(test_prediction,Y_test)
acc_train=accuracy_score(train_pre,Y_train)
print("Accuracy: {:.2f}%".format(acc))
print("Accuracy: {:.2f}%".format(acc_train))
# Out:
# Accuracy: 1.00%
# Accuracy: 0.99%
